# %% [markdown]
# # Variables BuiltIn Functions
# ### Day 2/30

# %%
from itertools import product

print("hello")
# Out:
# hello

# %%
# we can't use from this keywords because the python knows them as builtin function not as assigned functions
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
dir("sajdn".upper())
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
print("ksjnadk".__add__("asdad"))
# Out:
# ksjnadkasdad

# %%
exit()

# %%
"""
Python variables Name Rules
- a variable name must start with a letter or the underscore character
- A variable name cannot start with a number
- A Variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _)
- Variable names are case-sensitive (firstname, firstName,FIRSTNAME) are different variables)

if you want to use python keywords as variable write them with underscore(Example: _if, _while, _print)

Invalid Variables names:
first-name
first@name
num-1
1num

Many python developers uses snake case variable naming conventions.
first_name, last_name, engine_rotation_speed
"""

# %%
# Declaring Multiple Variable in a Line
first_name, last_name, country = "asjdas", "qweqwe", 'uzbekistan'
print(first_name)
print(last_name)
print(country)
# Out:
# asjdas
# qweqwe
# uzbekistan

# %%
# input() - let us get information from user
name = input("what's yout name")
print(name)
# Out:
# asdasd

# %% [markdown]
# #### DataTypes
# Different python data types
#
# Let's declare variables with various data types
#
# - 'asdad' - str
# - hdfjbvj - str
# - 10      - int
# - 3.14    - float
# - 1 + 1j  - complex
# - True    - bool
# - [1,2,3] - list
# - {'name':'adsad"} - dict
# - (1,2,4) - tuple
# - zip([1,2],[3,4])  - zip

# %% [markdown]
# Converting one data type to another data type. we use *int(), float(), str(), list, set*
#
# > if you are doing arithmetic operations string numbers should be converted to *int* or *float*. if it is not, it will cause a problem.

# %%
# int to float
num_int = 10
num_float = float(10)

# float to int
gravity = 9.81
gravity_int = int(gravity)

#int to str
num_int = 19
num_str = str(num_int)

# str to int
num_str = '10'
num_int = int(num_int)

# str to list
first_name = "feruzbek"
first_name_to_list = list(first_name)
print(first_name_to_list)
# Out:
# ['f', 'e', 'r', 'u', 'z', 'b', 'e', 'k']

# %% [markdown]
# declare - to state, announcee, or express something clearly

# %% [markdown]
# # Exercises - Day 2
#
# ### Exercises: Level 1
#
# Inside 30DaysOfPython create a folder called day_2. Inside this folder create a file named variables.py
# 1. Write a python comment saying 'Day 2: 30 Days of python programming'
# 2. Declare a first name variable and assign a value to it
# 3. Declare a last name variable and assign a value to it
# 4. Declare a full name variable and assign a value to it
# 5. Declare a country variable and assign a value to it
# 6. Declare a city variable and assign a value to it
# 7. Declare an age variable and assign a value to it
# 8. Declare a year variable and assign a value to it
# 9. Declare a variable is_married and assign a value to it
# 10. Declare a variable is_true and assign a value to it
# 11. Declare a variable is_light_on and assign a value to it
# 12. Declare multiple variable on one line
#
# ### Exercises: Level 2
#
# 1. Using the len() built-in function, find the length of your first name
# 2. Compare the length of your first name and your last name
# 3. Declare 5 as num_one and 4 as num_two
# 4. Add num_one and num_two and assign the value to a variable total
# 5. Subtract num_two from num_one and assign the value to a variable diff
# 6. Multiply num_two and num_one and assign the value to a variable product
# 7. Divide num_one by num_two and assign the value to a variable division
# 8. Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
# 9. Calculate num_one to the power of num_two and assign the value to a variable exp
# 10. Find floor division of num_one by num_two and assign the value to a variable floor_division
# 11. The radius of a circle is 30 meters.
# 12. Calculate the area of a circle and assign the value to a variable name of area_of_circle
# 13. Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
# 14. Take radius as user input and calculate the area.
# 15. Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names
# 16. Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords

# %%
# Exercises: Level 1

# 2.
# "Day2: 30 days of python programming

# 3
first_name = 'Feruzbek'

# 4
last_name = "Bakoev"

# 5
full_name = f"{first_name} {last_name}"

# 6
country = "uzbekistan"

# 7
city = 'tashkent'

# 8
age = 21

# 9
year = 2026

#10
is_married = False

#11
is_true = False

#12
is_light_on = False

#13
first_name, last_name = 'Feruzbek', 'Bakoev'

# %%
# Exercises: Level 2
#1
print(type(full_name))

# 2, 3
print(len(first_name))
print(len(last_name))

# 4
num_one = 5
num_two = 4

# 5
total = num_one + num_two
print(total)

# 6
diff = num_two - num_one
print(diff)

# 7
product = num_one * num_two
print(product)

# 8
division = num_one / num_two
print(division)

# 9
remainder = num_one % num_two
print(remainder)

#10
exp = num_one ** num_two
print(exp)

#11
floor_division = num_one // num_two
print(floor_division)
#12
pi = 3.14
l = 30 # l =2*pi*r
area_of_circle = l ** 2 / 4 * pi
print(area_of_circle)

# circumference of a circle - perimetr
# Out:
# <class 'str'>
# 8
# 6
# 9
# -1
# 20
# 1.25
# 1
# 625
# 1
# 706.5

# %%
#DONE
