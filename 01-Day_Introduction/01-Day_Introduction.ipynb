# %% [markdown]
# # Introduction
# ## Day 1/30

# %%
print("Hola")
# Out:
# Hola

# %%
print(2 + 3) #additional
print(3 - 1) # substraction
print(2 * 3) # multiplication
print(3 - 2) # substraction
print(3 / 2) # division
print(3 ** 2) # exponential
print(5 % 2) # modules - qoldig'ini olib beradi
print(5 // 2) # floor division operator - butun qismini beradi
# Out:
# 5
# 2
# 6
# 1
# 1.5
# 9
# 1
# 2

# %%
print(type(10))  # Int
print(type(3.14))   # Float
print(type(1 + 3j))  # Complex
print(type('asjdnasd'))   # String
print(type([1,2,3]))    # List
print(type({'name': 'ashdasd'}))   # Dictionary
print(type({3.4,5,6}))   # Tuple
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
